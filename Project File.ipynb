# %%
import requests
import json
import matplotlib
import matplotlib.pyplot as plt
import plotly 
import plotly.plotly as py     
import plotly.graph_objs as go  
import cufflinks as cf
import pandas as pd
import folium
import warnings

# %%
currencies = []

while True:
    coin = input(str("Enter currency to be added to portfolio: ")).lower()
    if coin == 'bitcoin':
        bitcoin_url = 'https://api.coinmarketcap.com/v1/ticker/bitcoin/'
        bitcoin_request = requests.get(bitcoin_url)
        bitcoin_reply = bitcoin_request.json()
        bitcoin_json = bitcoin_reply[0]
        currencies.append(bitcoin_json)
    elif coin == 'dogecoin':
        dogecoin_url = 'https://api.coinmarketcap.com/v1/ticker/dogecoin/'
        dogecoin_request = requests.get(dogecoin_url)
        dogecoin_reply = dogecoin_request.json()
        dogecoin_json = dogecoin_reply[0]
        currencies.append(dogecoin_json)
    elif coin == 'litecoin':
        litecoin_url = 'https://api.coinmarketcap.com/v1/ticker/litecoin/'
        litecoin_request = requests.get(litecoin_url)
        litecoin_reply = litecoin_request.json()
        litecoin_json = litecoin_reply[0]
        currencies.append(litecoin_json)
    elif coin == 'ripple':
        ripple_url = 'https://api.coinmarketcap.com/v1/ticker/ripple/'
        ripple_request = requests.get(ripple_url)
        ripple_reply = ripple_request.json()
        ripple_json = ripple_reply[0]
        currencies.append(ripple_json)
    elif coin == 'iota':
        iota_url = 'https://api.coinmarketcap.com/v1/ticker/iota/'
        iota_request = requests.get(iota_url)
        iota_reply = iota_request.json()
        iota_json = iota_reply[0]
        currencies.append(iota_json)
    elif coin == 'ethereum':
        ethereum_url = 'https://api.coinmarketcap.com/v1/ticker/ethereum/'
        ethereum_request = requests.get(ethereum_url)
        ethereum_reply = ethereum_request.json()
        ethereum_json = ethereum_reply[0]
        currencies.append(ethereum_json)
    elif coin == 'stop':
        break
    else:
        print("Sorry, that is not a recognized input")
dataframe = pd.DataFrame(currencies).set_index(['name', 'symbol'])
dataframe
# Out:
# Enter currency to be added to portfolio: bitcoin
# Enter currency to be added to portfolio: litecoin
# Enter currency to be added to portfolio: iota
# Enter currency to be added to portfolio: stop
#                 24h_volume_usd available_supply        id last_updated  \
# name     symbol
# Bitcoin  BTC     12785100000.0       16732937.0   bitcoin   1512946753
# Litecoin LTC      1070150000.0       54242708.0  litecoin   1512946741
# IOTA     MIOTA     569088000.0     2779530283.0      iota   1512946769
#
#                 market_cap_usd    max_supply percent_change_1h  \
# name     symbol
# Bitcoin  BTC      249349207293    21000000.0             -0.73
# Litecoin LTC      7882496106.0    84000000.0             -0.47
# IOTA     MIOTA   11204647910.0  2779530283.0             -0.19
#
#                 percent_change_24h percent_change_7d   price_btc price_usd  \
# name     symbol
# Bitcoin  BTC                 -0.59             29.77         1.0   14901.7
# Litecoin LTC                 -5.27             42.37  0.00979545   145.319
# IOTA     MIOTA              -12.95            105.26  0.00027172   4.03113
#
#                 rank  total_supply
# name     symbol
# Bitcoin  BTC       1    16732937.0
# Litecoin LTC       6    54242708.0
# IOTA     MIOTA     4  2779530283.0

# %%
currencies
# Out:
# [{'24h_volume_usd': '12941000000.0',
#   'available_supply': '16732912.0',
#   'id': 'bitcoin',
#   'last_updated': '1512945853',
#   'market_cap_usd': '252377491822',
#   'max_supply': '21000000.0',
#   'name': 'Bitcoin',
#   'percent_change_1h': '-0.13',
#   'percent_change_24h': '0.85',
#   'percent_change_7d': '31.29',
#   'price_btc': '1.0',
#   'price_usd': '15082.7',
#   'rank': '1',
#   'symbol': 'BTC',
#   'total_supply': '16732912.0'},
#  {'24h_volume_usd': '569220000.0',
#   'available_supply': '2779530283.0',
#   'id': 'iota',
#   'last_updated': '1512945869',
#   'market_cap_usd': '11239753377.0',
#   'max_supply': '2779530283.0',
#   'name': 'IOTA',
#   'percent_change_1h': '-0.79',
#   'percent_change_24h': '-12.7',
#   'percent_change_7d': '106.66',
#   'price_btc': '0.00026975',
#   'price_usd': '4.04376',
#   'rank': '4',
#   'symbol': 'MIOTA',
#   'total_supply': '2779530283.0'},
#  {'24h_volume_usd': '197431000.0',
#   'available_supply': '38739144847.0',
#   'id': 'ripple',
#   'last_updated': '1512946141',
#   'market_cap_usd': '9111369390.0',
#   'max_supply': '100000000000',
#   'name': 'Ripple',
#   'percent_change_1h': '0.01',
#   'percent_change_24h': '-4.32',
#   'percent_change_7d': '-7.81',
#   'price_btc': '0.00001574',
#   'price_usd': '0.235198',
#   'rank': '5',
#   'symbol': 'XRP',
#   'total_supply': '99993093880.0'}]

# %%
df = pd.DataFrame(currencies).set_index(['name', 'symbol'])
df
# Out:
#                24h_volume_usd available_supply       id last_updated  \
# name    symbol
# Bitcoin BTC     12941000000.0       16732912.0  bitcoin   1512945853
# IOTA    MIOTA     569220000.0     2779530283.0     iota   1512945869
# Ripple  XRP       197431000.0    38739144847.0   ripple   1512946141
#
#                market_cap_usd    max_supply percent_change_1h  \
# name    symbol
# Bitcoin BTC      252377491822    21000000.0             -0.13
# IOTA    MIOTA   11239753377.0  2779530283.0             -0.79
# Ripple  XRP      9111369390.0  100000000000              0.01
#
#                percent_change_24h percent_change_7d   price_btc price_usd  \
# name    symbol
# Bitcoin BTC                  0.85             31.29         1.0   15082.7
# IOTA    MIOTA               -12.7            106.66  0.00026975   4.04376
# Ripple  XRP                 -4.32             -7.81  0.00001574  0.235198
#
#                rank   total_supply
# name    symbol
# Bitcoin BTC       1     16732912.0
# IOTA    MIOTA     4   2779530283.0
# Ripple  XRP       5  99993093880.0
